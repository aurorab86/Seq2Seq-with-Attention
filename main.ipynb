# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import numpy as np

from dataset import *
from models import *
from model_training import *
from model_test import test_model

# %%
seq_length_min, seq_length_max, batch_size = 1, 20, 100

# %%
model = AttentionSeq2Seq(12, 25, 12)

# %%
optimizer = optim.Adam(model.parameters())

# %%
model_train(optimizer, model, seq_length_min, seq_length_max)
# Out:
# loss: 0.20084452671185088, accuracy: 0.9400072852433168

# %%
torch.save(model.state_dict(), 'model_state_dict.pt')

# %%
test_model(model)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# i = 0
# i = 5000
# i = 10000
# i = 15000
# i = 20000
# i = 25000
# i = 30000
# i = 35000
# i = 40000
# i = 45000
